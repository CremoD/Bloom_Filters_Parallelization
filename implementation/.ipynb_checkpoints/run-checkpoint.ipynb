# %%
import os
import sys
import time

# %%
command = ""
if sys.platform == 'win32':
    command = "del"
else:
    command = "rm"

# %%
os.system(f"cd ../results && {command} *.csv")
os.system("cd ../baseline")
# Out:
# 0

# %%
print(os.popen("dir").read())
# Out:
#  Datentr„ger in Laufwerk C: ist Windows-SSD
#  Volumeseriennummer: E214-77B3
#
#  Verzeichnis von C:\Users\honzi\Documents\UNI\InPaCo\inpacobloomfilters\baseline
#
# 13.04.2021  14:14    <DIR>          .
# 13.04.2021  14:14    <DIR>          ..
# 09.04.2021  11:37    <DIR>          .ipynb_checkpoints
# 26.03.2021  11:35             2.382 Atomic.c
# 09.04.2021  14:00           101.332 atomic.exe
# 20.03.2021  14:56            19.200 baseline
# 20.03.2021  14:56             2.277 Baseline.c
# 09.04.2021  13:57           101.332 baseline.exe
# 13.04.2021  14:10             2.440 BaselineOpenMP.c
# 13.04.2021  14:10           101.332 baseline_omp.exe
# 26.03.2021  11:33    <DIR>          bloom
# 20.03.2021  14:56    <DIR>          dataloader
# 26.03.2021  11:33    <DIR>          experiment
# 25.03.2021  11:15             2.469 LockStriping.c
# 25.03.2021  11:15           105.997 lock_striping.exe
# 13.04.2021  14:09            18.404 Makefile
# 20.03.2021  14:56    <DIR>          murmur3
# 13.04.2021  14:10             2.478 OMPReduction.c
# 09.04.2021  14:10           101.332 reduction.exe
# 13.04.2021  14:14             8.169 run.ipynb
# 13.04.2021  14:13               937 run.py
# 20.03.2021  14:56    <DIR>          utility
# 20.03.2021  14:56    <DIR>          xoshiro256starstar
#               14 Datei(en),        570.081 Bytes
#                9 Verzeichnis(se), 153.817.980.928 Bytes frei

# %%
time_list = []

# %%
for i in range(10):
    start = time.time()
    #print(f"{i}\n")
    #print(os.system('make full_baseline out=baseline'))
    #print("baseline done\n")
    #print(os.system('make full_omp out=omp'))
    #print("omp done\n")
    #print(os.system('make full_atomic out=atomic'))
    #print("atomic done\n")
    print(os.system('make full_reduction out=reduction'))
    print("reduction done\n")
    end = time.time()
    print(f"Time elapsed: {(end - start)/60} min")
    time_list.append((end - start)/60)
    print("=====================================================================\n")
# Out:
# 0
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 35.68820668458939 min
# =====================================================================
#
# 1
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.39649245738983 min
# =====================================================================
#
# 2
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.701873695850374 min
# =====================================================================
#
# 3
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.694075326124825 min
# =====================================================================
#
# 4
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.53158377408981 min
# =====================================================================
#
# 5
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.59428399801254 min
# =====================================================================
#
# 6
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.24535418748856 min
# =====================================================================
#
# 7
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.66662120024363 min
# =====================================================================
#
# 8
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 37.848105688889824 min
# =====================================================================
#
# 9
#
# 0
# baseline done
#
# 0
# omp done
#
# 0
# atomic done
#
# 0
# reduction done
#
# Time elapsed: 36.9011389931043 min
# =====================================================================

# %%
my_sum = 0
for i in time_list:
    my_sum += i
print(f"Total time: {my_sum}")
# Out:
# Total time: 373.26773600578304
